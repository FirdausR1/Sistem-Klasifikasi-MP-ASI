# %%
import pandas as pd 
data = 'DATASET/Data_Rekomendasi_Menu.xlsx'
sheet = 'Sheet1'

dataset = pd.read_excel(data,sheet_name=sheet)
print(dataset.head())
# Out:
#    ID                                       Nama Makanan Umur Balita (bulan)  \
# 0   1  Bubur Singkong Isi Ikan dan Ayam dengan Saus J...                 6-8
# 1   2                             Bubur Soto Ayam Santan                 6-8
# 2   3                      Bubur Sup Daging Kacang Merah                 6-8
# 3   4                   Bubur Kanju Rumbi Ayam dan Udang                 6-8
# 4   5                      Puding Kentang Ayam dan Telur                 6-8
#
#                                                Bahan  \
# 0  75 gr singkong putih, 15 gr daging ikan kembun...
# 1  60 gr nasi, 45 gr daging ayam cincang, 30 gr t...
# 2  50 gr nasi, 30 gr daging ayam cincang, 25 gr t...
# 3  60 gr nasi putih, 30 gr daging ayam, 20 gr uda...
# 4  100 gr kentang, 30 gr daging ayam cincang, 10 ...
#
#                                         Cara Membuat  Kalori (kkal)  \
# 0  Tumis bumbu, tambahkan air kaldu dan bahan lai...           91.0
# ...
